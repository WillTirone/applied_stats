# %%
from module import Statistics_OOP as st

# %% [markdown]
# # About this module
#
# This module is intended to explore object-oriented programming implementations of common statistical distributions. The actual source code is located under the "module" folder in the main repository directory and is imported above.
#
# Each distribution is created as its own class with the pdf, plotting, and probability calculations as separate methods that can then be called on the class object (as demonstrated below).

# %% [markdown]
# ## Normal Distribution
#
# Where X is a normal random variable:
#
# $X \sim N(\mu,\sigma^{2})\$
#
# The pdf of the normal distribution is defined as follows:
#
# $
# \begin{equation}
# f(x) = \frac{1}{\sqrt{2\pi\sigma^2}}e^{{-\frac{1}{2}}(\frac{x-\mu}{\sigma})^2}
# \end{equation}
# $
#
# Probabilities are calculated, by default, as follows:
#
# $
# \int_{-\infty}^{0} \frac{1}{\sqrt{2\pi\sigma^2}}e^{{-\frac{1}{2}}(\frac{x-\mu}{\sigma})^2} dx
# $
#
# Where the upper limit is the optional critical value argument. As shown in the second normal distribution example, this can be changed to calculate different probabilities but will always calculate the area the the left of the c.v.

# %%
#a standard normal r.v. (E(x)=0, Var(x)=1)
a = st.Norm_rv(0,1)
a.plot_pdf() 
a.probability_calc()
# Out:
# 'P(X<crit_val) is 0.5 with an error estimate of 0.0'

# %%
# mean = 0, variance = 7, and a critical value of -2.5
b = st.Norm_rv(.2,7,100) 
b.plot_pdf(cv_probability=True)
b.probability_calc()

# %%
q = st.ChiSq_rv(4,crit_value=7)
q.plot_pdf(cv_probability=True)
q.probability_calc()
# Out:
# 'P(X>crit_val) is 0.13589 with an error estimate of 0.0'

# %%
z = st.ChiSq_rv(120,crit_value=120)
z.plot_pdf(cv_probability=True)
z.probability_calc()
# Out:
# 'P(X>crit_val) is 0.48283 with an error estimate of 0.0'

# %%
t = st.t_rv(5,1)
t.plot_pdf(cv_probability=True)
t.probability_calc()
# Out:
# 'P(X>crit_val) is 0.18161 with an error estimate of 0.0'

# %%
#probability calculation is not working correctly
f = st.F_rv(5,5,1.67)
f.plot_pdf(cv_probability=True)
f.probability_calc()
# Out:
# 'P(X>crit_val) is 1.47034 with an error estimate of 0.0'
